# %% [markdown]
# ## Loading Libraries

# %%
import pandas as pd
import re
import requests
import time
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Generating URLs

# %%
from datetime import date, timedelta

# Archive URL
archive_url = 'https://www.thehindu.com/archive/web/'
dates = []

# Dates for which we will scrape data

start_date = date(2016, 7, 7)
end_date = date(2013, 8, 1)
delta = timedelta(days=1)

# This object will store the scraped data
data_dictionary = {}

# Dates will be appended to end of URL
while start_date >= end_date:  
    dates.append(start_date.strftime("%Y/%m/%d"))   
    data_dictionary[start_date.strftime("%Y/%m/%d")] = {}
    start_date -= delta

print(dates)
# print(data_dictionary)
# Out:
# ['2016/07/07', '2016/07/06', '2016/07/05', '2016/07/04', '2016/07/03', '2016/07/02', '2016/07/01', '2016/06/30', '2016/06/29', '2016/06/28', '2016/06/27', '2016/06/26', '2016/06/25', '2016/06/24', '2016/06/23', '2016/06/22', '2016/06/21', '2016/06/20', '2016/06/19', '2016/06/18', '2016/06/17', '2016/06/16', '2016/06/15', '2016/06/14', '2016/06/13', '2016/06/12', '2016/06/11', '2016/06/10', '2016/06/09', '2016/06/08', '2016/06/07', '2016/06/06', '2016/06/05', '2016/06/04', '2016/06/03', '2016/06/02', '2016/06/01', '2016/05/31', '2016/05/30', '2016/05/29', '2016/05/28', '2016/05/27', '2016/05/26', '2016/05/25', '2016/05/24', '2016/05/23', '2016/05/22', '2016/05/21', '2016/05/20', '2016/05/19', '2016/05/18', '2016/05/17', '2016/05/16', '2016/05/15', '2016/05/14', '2016/05/13', '2016/05/12', '2016/05/11', '2016/05/10', '2016/05/09', '2016/05/08', '2016/05/07', '2016/05/06', '2016/05/05', '2016/05/04', '2016/05/03', '2016/05/02', '2016/05/01', '2016/04/30', '2016/04/29', '2016/04/28', '20
# ...

# %% [markdown]
# ## Fetching data for a particular day

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

## The URL
url = 'https://www.thehindu.com/archive/web/2016/12/06/'

# Request url content
page = requests.get(url, headers = headers)
soup = bs(page.content, 'html.parser')

# %%
# Find all Sections for the URL and articles in each section
for s in soup.find('div', class_ = 'tpaper-container').find_all('section'):
    print(s.find('h2').get_text().strip())
    for a in s.find('div', class_= 'col-lg-12 col-md-12 col-sm-12 col-xs-12').find_all('a'):
        print(a['href'])
# Out:
# other sports
# https://www.thehindu.com/sport/other-sports/Jeho-bags-maiden-title/article16768652.ece
# https://www.thehindu.com/sport/other-sports/The-phenomenal-rise-of-Suheil-Vahedi/article16765843.ece
# https://www.thehindu.com/sport/other-sports/Kabaddi-academy-soon-SAAP-chief/article16765182.ece
# races
# https://www.thehindu.com/sport/races/Rousseau-catches-the-eye/article16767469.ece
# https://www.thehindu.com/sport/races/Mission-Blue-shows-out/article16767454.ece
# tennis
# https://www.thehindu.com/sport/tennis/No-Roger-or-Serena-but-IPTL-promises-to-get-bigger/article16767742.ece
# technology
# https://www.thehindu.com/sci-tech/technology/do-mobile-phones-and-technology-interfere-with-the-plot-of-a-good-thriller/article16768138.ece
# gadgets
# https://www.thehindu.com/sci-tech/technology/gadgets/Life-of-the-party/article16768159.ece
# https://www.thehindu.com/sci-tech/technology/gadgets/Recreating-the-Potter-universe/article16765437.ece
# ...

# %% [markdown]
# ## Fetching data for all the urls

# %%
## Some helper functions to strip html tags
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

## Example code to get text from article
# Request url content
url = 'https://www.thehindu.com/news/national/unnao-rape-case-to-be-transferred-out-of-district-sc-demands-cbi-officers-presence-by-12-noon/article28780551.ece'
page = requests.get(url, headers = headers)
soup = bs(page.content, 'html.parser')
ps = (soup.find('div', class_ = 'article').find_all('p'))

string = ''
for p in ps:
    string += (strip_tags(p.get_text()))
string
# Out:
# "\nA view of the Supreme Court of India. File \xa0 | Photo Credit: The Hindu The Supreme Court on Thursday transferred five cases of crimes committed against the Unnao rape survivor and her family from a CBI court in Lucknow to its counterpart in Delhi and ordered the Uttar Pradesh government to pay her ₹25 lakh as interim compensation.A Bench led by Chief Justice of India (CJI) Ranjan Gogoi ordered the trial in the Unnao cases to be held on a day-to-day basis and completed within 45 days. The court even the extra mile of zeroing in on the trial judge.\n\n\nAlso Read\n\n\n\n\n\nKuldeep Sengar suspended from party long ago: U.P. BJP chief \n\n\n\n\nKuldeep Sengar suspended from party long ago: U.P. BJP chief Four of these cases include the rape of the minor on June 4, 2017; a false case hoisted against her father under the Arms Act by conniving police officers; the custodial death of her father, who was beaten up before being taken into custody; and a second instance of gang rape of t
# ...

# %%
## Function to get article text from links
def get_article_text(s):
    
    print(len(s.find('div', class_= 'col-lg-12 col-md-12 col-sm-12 col-xs-12').find_all('a')))
    articles = []
    
    # For each link in the hindu archive section
    for a in s.find('div', class_= 'col-lg-12 col-md-12 col-sm-12 col-xs-12').find_all('a'):
        
        print(a['href'])
        # Request url content
        page = requests.get(a['href'], headers = headers)
        soup = bs(page.content, 'html.parser')
        
        # Get the title of article
        title = soup.find('div', class_ = 'article').find('h1', class_ = 'title')
        
        # Get the paragraphs article
        paragraphs = (soup.find('div', class_ = 'article').find_all('p'))
        article_text = ''
        
        # Append text for each paragraph found in html
        for paragraph in paragraphs:
            article_text += (strip_tags(paragraph.get_text()))
        
        if title != None:
            articles.append((title.get_text(), article_text))
        else:
            articles.append(('Title Not Found', article_text))
            
    return articles

# %%
## Fetching data for all urls

## Define the sections we would like to scrape
sections = set(['economy', 'industry', 'markets', 'business']) 

for date in dates:
    
    print(date)
    # Request url content
    page = requests.get(archive_url + date, headers = headers)
    soup = bs(page.content, 'html.parser')

    for section in sections:
        data_dictionary[date][section] = []
        
    # Find all Sections for the URL and articles in each section
    for s in soup.find('div', class_ = 'tpaper-container').find_all('section'):
        section = (s.find('h2').get_text().strip())
        
        # Get links for each section that I am interested in
        if section in sections:
            data_dictionary[date][section] = get_article_text(s)
        
    # Sleeping for 0.001 seconds (Not required for The Hindu)
    time.sleep(0.001)
# Out:
# 2016/07/07
# 11
# https://www.thehindu.com/business/PNB-moves-up-4.5-pc-on-subsidiary%E2%80%99s-IPO-plan/article14475850.ece
# https://www.thehindu.com/business/LampT-Construction-wins-Rs-3598-cr-job-orders/article14475849.ece
# https://www.thehindu.com/business/Galaxy-phones-drive-17-percent-jump-in-Samsungs-2Q-profit/article14475830.ece
# https://www.thehindu.com/business/Petronet-plans-Rs.5K-cr.-terminal-in-Bangladesh/article14474632.ece
# https://www.thehindu.com/business/New-port-in-Tamil-Nadu-may-lead-to-traffic-imbalance-in-the-region/article14474631.ece
# https://www.thehindu.com/business/ICRA-sees-pick-up-in-rural-demand/article14474628.ece
# https://www.thehindu.com/business/New-tax-standard-deferred-by-one-year/article14474627.ece
# https://www.thehindu.com/business/Meghwal-Gangwar-take-over-as-MoS-Finance/article14474626.ece
# https://www.thehindu.com/business/States-could-have-worsening-financials-in-FY17-Yes-Bank/article14474621.ece
# ...

# %%
dictionary_df = {}

dictionary_df['Date'] = []
dictionary_df['Section'] = []
dictionary_df['Title'] = []
dictionary_df['Article'] = []

for date, sections in data_dictionary.items():
        
    for section, articles in sections.items():
        
        for article in articles:
            
            dictionary_df['Date'].append(date)
            dictionary_df['Section'].append(section)
            dictionary_df['Title'].append(article[0])
            dictionary_df['Article'].append(article[1])

# %%
df = pd.DataFrame.from_dict(data=dictionary_df)
df.head()
# Out:
#          Date   Section                                              Title  \
# 0  2016/07/07   economy  \nBrexit could push EU toward better integrati...
# 1  2016/07/07   economy  \nIndia-UK Free Trade Agreement may be easier ...
# 2  2016/07/07   economy  \nRBI Central Board discusses macroeconomic de...
# 3  2016/07/07  industry  \nGovt. mulling raising FDI cap in newspapers,...
# 4  2016/07/07  industry  \nDiesel variants of Linea, Punto EVO and Avve...
#
#                                              Article
# 0  International Monetary Fund chief Christine La...
# 1  A Free Trade Agreement between India and the U...
# 2  \nThe Reserve Bank of India's Central Board me...
# 3  The government is mulling a raise in foreign d...
# 4  \nThe Fiat logo is seen on a car on display in...

# %%
## Remove commas
df.to_csv('data_2016_07_07_to_2013_08_01.csv', index=False)
df.Title = df.Title.str.replace(',', '')
df.Article = df.Article.str.replace(',', '')
df.to_csv('data_2016_07_07_to_2013_08_01_comma_removed.csv', index=False)
